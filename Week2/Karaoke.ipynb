# %%
class Karaoke:
    def displayLyrics(self):
        print('I hear the ocean from far away\n\n')
        print('I walk across the dream over the forest\n\n')
        print('And go towards the path which is clearer\n\n')

karaoke_obj=Karaoke()
karaoke_obj.displayLyrics()
