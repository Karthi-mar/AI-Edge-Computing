# %%
import random
rand_list = [ "are you a robot ?","Are you not a Human","Dont you have tactile sense ?"]
print(random.choice(rand_list))
chk = input()
if chk =="yes":
  print("\nSorry! Robots are not allowed here !")
else:
  print("\nWelcome to our website!")
# Out:
# Dont you have tactile sense ?
